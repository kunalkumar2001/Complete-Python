# %% [markdown]
# # Python Exception Handling

# %% [markdown]
# - The **try** block lets you test a block of code for errors.
#
# - The **except** block lets you handle the error.
#
# - The **else** block lets you execute code when there is no error.
#
# - The **finally** block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ## Exception Handling
# - When an error occurs, or exception as we call it, Python will normally stop and generate an error message.
#
# - These exceptions can be handled using the **try** statement:

# %%
a = 10

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    ## code block where exception can occur
    a=b
except:
    print("Some problem may have occured")
# Out:
# Some problem may have occured

# %%
try:
    ## code block where exception can occur
    a=b
except Exception as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    ## code block where exception can occur
    a=b
    
except NameError as ex1:
    print(" The user have not defined the variable")
except Exception as ex:
    print(ex)
# Out:
#  The user have not defined the variable

# %%
try:
    a=1
    b ="s"
    c = a+b
    
except NameError as ex1:  
    print(" The user have not defined the variable")
except TypeError as ex2:
    print(" Try to make similar datatypes")
except Exception as ex:
    print(ex)
# Out:
#  Try to make similar datatypes

# %%
    a=1
    b ="s"
    c = a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 a=1
#       2 b ="s"
# ----> 3 c = a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    a = int(input("Enter the number 1 "))
    b = int(input("Enter the number 2 "))
    c = a+b
    d = a*b
    e = a/b
    print(c)
    print(d)
    print(e)
    
except NameError as ex1:  
    print(" The user have not defined the variable")
except TypeError as ex2:
    print(" Try to make similar datatypes")
except Exception as ex:
    print(ex)
# Out:
# Enter the number 1 10
# Enter the number 2 2
# 12
# 20
# 5.0

# %%
try:
    a = int(input("Enter the number 1 "))
    b = int(input("Enter the number 2 "))
    c = a+b
    d = a*b
    e = a/b
    
except NameError as ex1:  
    print(" The user have not defined the variable")
except TypeError as ex2:
    print(" Try to make similar datatypes")
except ZeroDivisionError as ex3:
    print("Please provided the number greater than zero")
except Exception as ex:
    print(ex)
    
else:
    print(c)
    print(d)
    print(e)
    
finally:
    print("The excution is done")
# Out:
# Enter the number 1 10
# Enter the number 2 5
# 15
# 50
# 2.0
# The excution is done

# %%
try:
    a = int(input("Enter the number 1 "))
    b = int(input("Enter the number 2 "))
    c = a+b
    d = a*b
    e = a/b
    
except NameError as ex1:  
    print(" The user have not defined the variable")
except TypeError as ex2:
    print(" Try to make similar datatypes")
except ZeroDivisionError as ex3:
    print("Please provided the number greater than zero")
except Exception as ex:
    print(ex)
    
else:
    print(c)
    print(d)
    print(e)
    
finally:
    print("The excution is done")
# Out:
# Enter the number 1 10
# Enter the number 2 0
# Please provided the number greater than zero
# The excution is done

# %% [markdown]
# ## Custom Exception:-

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("Enter the year of birth "))
age = 2024-year
try:
    if age<30 and age>20:
        print("This age is valid. You can applied this post")
    else:
        raise dobException
except dobException:
    print("This age is not valid")
# Out:
# Enter the year of birth 1998
# This age is valid. You can applied this post

# %%
x = -1

if x < 0:
    raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 x = -1
#       3 if x < 0:
# ----> 4     raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero

# %%
x = "hello"

if not type(x) is int:
    raise TypeError("Only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 x = "hello"
#       3 if not type(x) is int:
# ----> 4     raise TypeError("Only integers are allowed")
#
# TypeError: Only integers are allowed
