# %% [markdown]
# ## Sets:-
# - Sets are used to store multiple items in single variable.
# - A set is collection which is unorderd, unchangeable, and unidexed.
# - Set cannot have two items with same values.
# - Python's set class represents the mathematical notion of a set.This is based on a data structure known as a hash table

# %%
## Defining an empy set

set_var= set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
# Duplicate not allowed
set1 = {"apple","mango","cherry","apple"}
print(set1)
# Out:
# {'cherry', 'mango', 'apple'}

# %% [markdown]
# ### Access Set Items:-

# %% [markdown]
# - It cannot access itms in a set by referring to an index or key.
# - But you can loop through the set items using a 'for' loop or ask if a specified value is present in a set, by using the 'in' keyword.

# %%
#Example
set1 = {"apple","mango","cherry",}
for x in set1:
    print(x)
# Out:
# cherry
# mango
# apple

# %%
set1 = {"apple","mango","cherry"}
print("mango" in set1)
# Out:
# True

# %% [markdown]
# ### Change Items:-
# - Once a set is created, you cannot change its items, but you can add new items.

# %% [markdown]
# ### Add Items:-
# - To add one item to a set use the add() method.

# %%
set1 = {"apple","mango","cherry"}
set1.add("banana")
print(set1)
# Out:
# {'banana', 'cherry', 'mango', 'apple'}

# %% [markdown]
# - To add items from another set into the current set, use the update() method.

# %%
set1 = {"apple"}
set2 = {"banana"}
set1.update(set2)
print(set1
     )
# Out:
# {'banana', 'apple'}

# %% [markdown]
# #### Add any Iterable:-
# - The object in the update() method does not have to be a set, it can be any iterable object(sets, tuples, list, dictionaries).

# %%
set1 = {"apple","mango","cherry"}
list1 = ["kiwi","orange"]
set1.update(list1)
print(set1)
# Out:
# {'kiwi', 'cherry', 'mango', 'orange', 'apple'}

# %% [markdown]
# ### Remove Item:-
# - Use the remove() ot discard() method.

# %%
set1 = {"apple","mango","cherry"}
set1.remove("apple")
print(set1)
# Out:
# {'cherry', 'mango'}

# %%
set1 = {"apple","mango","cherry"}
set1.discard("mango")
print(set1)
# Out:
# {'cherry', 'apple'}

# %% [markdown]
# - Pop() method remove an item, but this method will remove a random item, so you cannot sure what item that gets removed.

# %% [markdown]
# - The del keywoed will delete the set complete.

# %% [markdown]
# ### Joint Sets:-
# - The union() method returns  a new set with all itms from both sets.

# %%
set1 = {"apple","mango","cherry"}
set2 = {1,2,3}
set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'cherry', 'mango', 'apple'}

# %% [markdown]
# - The Intersection_update() method will keep only common items that are present in both sides.

# %%
set1 = {"apple","mango","cherry"}
set2 = {"orange","mango","kiwi"}
set1.intersection_update(set2)
print(set1)
# Out:
# {'mango'}

# %%
set1 = {"apple","mango","cherry"}
set2 = {"orange","mango","kiwi"}
set3= set1.intersection(set2)
print(set3)
# Out:
# {'mango'}

# %% [markdown]
# ## Dictionary:-
# - Dictionaries are used to store data value in keys value pairs.
# - A dictionary is a collection which is ordered, changeable, and do not allow duplicate.
# - Dictionaries are written with curly brackets and have keys and values.

# %%
dic={}

# %%
type(dic)
# Out:
# dict

# %%
type(dict())
# Out:
# dict

# %%
set_ex={1,2,3,4,5}

# %%
type(set_ex)
# Out:
# set

# %%
# Let create a dictionary
dict1  = {"Brand":"Ford","Model":"Mustang","Year":1964}
print(dict1)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964}

# %%
print(dict1["Brand"])
# Out:
# Ford

# %%
#Dictionary Length
print(len(dict1))
# Out:
# 3

# %% [markdown]
# ### Dictionary items - data types:-
# - String, int, boolean, and list data types:

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
print(dict1)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 1964, 'Colors': ['red', 'White']}

# %%
print(dict1["Colors"])
# Out:
# ['red', 'White']

# %% [markdown]
# ### dict() constructor
# - It is also possible to use the dict() constructor to make a dict.

# %%
this_dict = dict(name="Kunal",age = 23,Country = "India")
print(this_dict)
# Out:
# {'name': 'Kunal', 'age': 23, 'Country': 'India'}

# %% [markdown]
# ### Accessing Keys:-
# - You can access the items of a dictionary by referring to its key name, inside square brackets[].

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
x = dict1["Brand"]
print(x)
# Out:
# Ford

# %%
# There is also a method called get() that will give you same result.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
x = dict1.get("Brand")

# %%
print(x)
# Out:
# Ford

# %% [markdown]
# ### Get Keys:-
# - The keys() method return a list of all keys in the dictionary.

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
x = dict1.keys()
print(x)
# Out:
# dict_keys(['Brand', 'Electric', 'Year', 'Colors'])

# %% [markdown]
# ### Get Values:-
# - The values() method return a list of all values in the dictionary

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
x = dict1.values()
print(x)
# Out:
# dict_values(['Ford', 'False', 1964, ['red', 'White']])

# %%
dict1["Year"] = 2020
print(x)
# Out:
# dict_values(['Ford', 'False', 2020, ['red', 'White']])

# %%
dict1["Model"] = "Mustang"
print(x)
# Out:
# dict_values(['Ford', 'False', 2020, ['red', 'White'], 'Mustang'])

# %%
print(dict1)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 2020, 'Colors': ['red', 'White'], 'Model': 'Mustang'}

# %% [markdown]
# ### Get Items:-

# %%
x = dict1.items()
print(x)
# Out:
# dict_items([('Brand', 'Ford'), ('Electric', 'False'), ('Year', 2020), ('Colors', ['red', 'White']), ('Model', 'Mustang')])

# %% [markdown]
# ### Changes Values:-

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
dict1["Colors"] = "Yellow"

# %%
print(dict1)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 1964, 'Colors': 'Yellow'}

# %%
# upadte Dictionary:-
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
dict1.update({"Year":2020})
print(dict1)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 2020, 'Colors': ['red', 'White']}

# %% [markdown]
# ### Adding Items:-
# - Adding an items to the dictionary is done by using a new index and assinging a value to it.

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964}

# %%
dict1["Color"] = ["red","white"]
print(dict1)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 1964, 'Color': ['red', 'white']}

# %% [markdown]
# ### Removing Items:-

# %%
# The pop() method removes the item with the specified key name.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
dict1.pop("Brand")
print(dict1)
# Out:
# {'Electric': 'False', 'Year': 1964, 'Colors': ['red', 'White']}

# %%
# The del() method also removes the item with the specified key name.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
del dict1["Brand"]
print(dict1)
# Out:
# {'Electric': 'False', 'Year': 1964, 'Colors': ['red', 'White']}

# %%
# The popitem() method removes the last inserted item.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
dict1.popitem()
print(dict1)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 1964}

# %%
# The clear() method empties the dictionary.
# The pop() method removes the item with the specified key name.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
dict1.clear()
print(dict1)
# Out:
# {}

# %% [markdown]
# ### Loop Method:-

# %%
# Print all keys name in the dictionary one by one.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
for x in dict1:
    print(x)
# Out:
# Brand
# Electric
# Year
# Colors

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
for x in dict1.keys():
    print(x)
# Out:
# Brand
# Electric
# Year
# Colors

# %%
# Print all values in the dictionary one by one.
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
for x in dict1:
    print(dict1[x])
# Out:
# Ford
# False
# 1964
# ['red', 'White']

# %%
for x in dict1.values():
    print(x)
# Out:
# Ford
# False
# 1964
# ['red', 'White']

# %%
for x,y in dict1.items():
    print(x,y)
# Out:
# Brand Ford
# Electric False
# Year 1964
# Colors ['red', 'White']

# %% [markdown]
# ### Copy Dictionary:-

# %%
dict1 = {"Brand":"Ford","Electric":"False","Year":1964,"Colors":["red","White"]}
my_dict = dict1.copy()
print(my_dict)
# Out:
# {'Brand': 'Ford', 'Electric': 'False', 'Year': 1964, 'Colors': ['red', 'White']}

# %% [markdown]
# ### Nested Dictionaries:-
# - A dictionary can contain dictionaries is called Nested dictionaries.

# %%
my_family = {"child1":{"Name":"Emil","Year":2004},
            "child2":{"Name":"Thomas","Year":2007},
            "child3":{"Name":"Linus","Year":2011}}
print(my_family)
# Out:
# {'child1': {'Name': 'Emil', 'Year': 2004}, 'child2': {'Name': 'Thomas', 'Year': 2007}, 'child3': {'Name': 'Linus', 'Year': 2011}}

# %%
child1 = {"Name":"Emil","Year":2004}
child2 = {"Name":"Thomas","Year":2007}
child3 = {"Name":"Linus","Year":2011}

my_family = {"child1":child1,"child2":child2,"child3":child3}
print(my_family)
# Out:
# {'child1': {'Name': 'Emil', 'Year': 2004}, 'child2': {'Name': 'Thomas', 'Year': 2007}, 'child3': {'Name': 'Linus', 'Year': 2011}}

# %%
# Access items in Nested Dictionaries:-
print(my_family["child2"]["Name"])
# Out:
# Thomas

# %% [markdown]
# ## Tuples
# - Tuple are used to store multiple items in a single variable.
# - A tuple is a collection which is ordered, unchangeable and allow duplicate value.
# - Tuples are written with round brackets().

# %%
## create an empty Tuples

my_tuple=tuple()

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple=()

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple=("Kunal","Ankur","John")
print(type(my_tuple))
print(my_tuple)
# Out:
# <class 'tuple'>
# ('Kunal', 'Ankur', 'John')

# %%
## Inbuilt function
my_tuple.count('Kunal')
# Out:
# 1

# %%
my_tuple.index('John')
# Out:
# 2

# %% [markdown]
# ### Create Tuple with one item:-
# - To create a tuple with only one item, you have to badd a comma after the item, otherwise Python will not recognize it as Tuple.

# %%
tup1 = ("apple")
type(tup1)
# Out:
# str

# %%
tup1 = ("apple",)
type(tup1)
# Out:
# tuple

# %% [markdown]
# ### The Touple () Constructor
# - It is also possible to use the tuple() constructor to make a tuple

# %%
lst = ["apple", "banana", "cherry"]
tup = tuple(lst)

print(tup)
print(type(tup))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %% [markdown]
# ### Access Tuple items:-
# - You can access tuple items by referring to the index number, inside the square brcakets[].

# %%
tup1 = ("apple", "banana", "cherry","mango","orange")
print(type(tup1))
print(tup1[1])
# Out:
# <class 'tuple'>
# banana

# %%
print(tup1[-1])
# Out:
# orange

# %%
print(tup1[2:5])
# Out:
# ('cherry', 'mango', 'orange')

# %%
if "apple" in tup1:
    print("Yes")
# Out:
# Yes

# %% [markdown]
# ### Change Tuple Values:-
# - Once a tuple is created, you cannot change its values. But there is a workaround, you can convert the tuple into a list and convert the list back into a tuple.

# %%
x = ("apple", "banana", "cherry","mango","orange")
y = list(x)
y[0] = "kiwi"
x = tuple(y)
print(x)
# Out:
# ('kiwi', 'banana', 'cherry', 'mango', 'orange')

# %% [markdown]
# #### Add items:-

# %%
x = ("apple", "banana", "cherry","mango","orange")
y = list(x)
y.append("kiwi")
x = tuple(y)
print(x)
# Out:
# ('apple', 'banana', 'cherry', 'mango', 'orange', 'kiwi')

# %% [markdown]
# #### Remove Items:-

# %%
x = ("apple", "banana", "cherry","mango","orange")
y = list(x)
y.remove("cherry")
x = tuple(y)
print(x)
# Out:
# ('apple', 'banana', 'mango', 'orange')

# %% [markdown]
# ### Add tuple to a tuple:-

# %%
x = ("apple", "banana", "cherry","mango","orange")
y = ("papaya",)
x +=y
print(x)
# Out:
# ('apple', 'banana', 'cherry', 'mango', 'orange', 'papaya')

# %% [markdown]
# ### Unpacking a Tuple:-

# %%
fruits = ("apple", "banana", "cherry")
green, yellow, red = fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# #### Using Asterisk:-
# - If the number of variables is less than the number of values, you can add an '*' to the variables name and the values will be assigned to the var in a list.

# %%
fruits = ("apple", "banana", "cherry","papaya","watermelon","mango")
green, yellow, *red = fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'papaya', 'watermelon', 'mango']

# %% [markdown]
# #### Loop through the index numbers:-
# -  You can also loop through the tuples items by referring to their index numbers.

# %%
fruits = ("apple", "banana", "cherry","papaya","watermelon","mango")
for i in range(len(fruits)):
    print(fruits[i])
# Out:
# apple
# banana
# cherry
# papaya
# watermelon
# mango

# %%
# Using a while loop
fruits = ("apple", "banana", "cherry", "papaya", "watermelon", "mango")
i = 0
while i < len(fruits):
    print(fruits[i])
    i += 1
# Out:
# apple
# banana
# cherry
# papaya
# watermelon
# mango

# %% [markdown]
# ### Join two tuple:-

# %%
tup1 = ("a","b","c")
tup2 = (1,2,3)
tup3 = tup1 + tup2
print(tup3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
tup1 = ("a","b","c")
tup2 = tup1*2
print(tup2)
# Out:
# ('a', 'b', 'c', 'a', 'b', 'c')
